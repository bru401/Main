# %%
# %sql
DROP TABLE IF EXISTS bronze.raw_data
--  DROP TABLE IF EXISTS silver._____
--  DROP TABLE IF EXISTS gold._____

# %%
# %sql
DROP DATABASE IF EXISTS marketing CASCADE

# %%
table_name = "bronze.raw_data"

if spark.catalog.tableExists(table_name):
    display(spark.sql(f"SELECT * FROM {table_name}"))
