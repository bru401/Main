# %%
# %sql
-- Bronze
DROP TABLE IF EXISTS bronze.raw_data;

# %%
# %sql
-- Silver
DROP TABLE IF EXISTS silver.dim_customer;
DROP TABLE IF EXISTS silver.dim_promo;
DROP TABLE IF EXISTS silver.dim_calendar;
DROP TABLE IF EXISTS silver.fact_sales;

# %%
# %sql
-- Gold
DROP TABLE IF EXISTS gold.customer_profile

# %%
# %sql
DROP DATABASE IF EXISTS bronze CASCADE;
DROP DATABASE IF EXISTS silver CASCADE;
DROP DATABASE IF EXISTS gold CASCADE;

# %%
# Testing Block
table_name = "bronze.raw_data"

if spark.catalog.tableExists(table_name):
    display(spark.sql(f"SELECT * FROM {table_name}"))
