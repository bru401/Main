# %% [markdown]
# # Creating Schema
# We'll start by creating an empty database.

# %%
# %sql
CREATE DATABASE marketing;

# %% [markdown]
# Then, we create the empty schema that will receive the raw data, currently stored in this very same GitHub folder. Through this we define the first constraints for the dataset, namely the type constraints for each column.

# %%
# %sql
CREATE TABLE IF NOT EXISTS marketing.ifood (
  ID INT,
  Year_Birth INT,
  Education STRING,
  Marital_Status STRING,
  Income INT,
  Kidhome INT,
  Teenhome INT,
  Dt_Customer DATE,
  Recency INT,
  MntWines INT,
  MntFruits INT,
  MntMeatProducts INT,
  MntFishProducts INT,
  MntSweetProducts INT,
  MntGoldProds INT,
  NumDealsPurchases INT,
  NumWebPurchases INT,
  NumCatalogPurchases INT,
  NumStorePurchases INT,
  NumWebVisitsMonth INT,
  AcceptedCmp3 INT,
  AcceptedCmp4 INT,
  AcceptedCmp5 INT,
  AcceptedCmp1 INT,
  AcceptedCmp2 INT,
  Complain INT,
  Z_CostContact INT,
  Z_Revenue INT,
  Response INT
)
