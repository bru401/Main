# %%
# %sql
CREATE SCHEMA marketing;

# %%
df = spark.read.csv("/Workspace/Users/bru401@gmail.com/Main/Data_Engineering/ml_project1_data.csv", header=True, inferSchema=True)
df.write.saveAsTable("marketing.ifood")
